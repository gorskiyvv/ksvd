# %%
import numpy as np
import re
import tensorflow as tf
from tensorflow.keras.layers import Dense, GRU, Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

texts_positive = [
    "Священна і правдива річ, Воля України!",
    "Ти диво, ти країно моя! Ти земле, ти світе мій!",
    "За країну нашу святую гинуть наші браття."
]

texts_negative = [
    "Сумно зриваються пісні дні",
    "Вітер віє, вітрила рве, відпливає корабель.",
    "Не коси, не коси, чорнобривії, та ти спиш і засинаєш."
]

texts = texts_positive + texts_negative
count_positive = len(texts_positive)
count_negative = len(texts_negative)

max_words_count = 1000
tokenizer = Tokenizer(num_words=max_words_count, filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n\r«»', lower=True, split=' ', char_level=False)
tokenizer.fit_on_texts(texts)

max_text_len = 10
data = tokenizer.texts_to_sequences(texts)
data_pad = pad_sequences(data, maxlen=max_text_len)

X = data_pad
Y = np.array([[1, 0]] * count_positive + [[0, 1]] * count_negative)

indices = np.random.choice(X.shape[0], size=X.shape[0], replace=False)
X = X[indices]
Y = Y[indices]

model_gru = Sequential()
model_gru.add(Embedding(max_words_count, 128, input_length=max_text_len))
model_gru.add(GRU(128, return_sequences=True))
model_gru.add(GRU(64))
model_gru.add(Dense(2, activation='softmax'))
model_gru.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=Adam(0.0001))

history_gru = model_gru.fit(X, Y, batch_size=32, epochs=50)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 5s 5s/step - loss: 0.6979 - accuracy: 0.3333
# Epoch 2/50
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6965 - accuracy: 0.3333
# Epoch 3/50
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6950 - accuracy: 0.3333
# Epoch 4/50
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6935 - accuracy: 0.5000
# Epoch 5/50
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6920 - accuracy: 0.5000
# Epoch 6/50
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6906 - accuracy: 0.6667
# Epoch 7/50
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6891 - accuracy: 0.6667
# Epoch 8/50
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6876 - accuracy: 0.6667
# Epoch 9/50
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6861 - accuracy: 0.6667
# Epoch 10/50
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6846 - accuracy: 0.6667
# Epoch 11/50
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6831 - accuracy: 0.6667
# Epoch 12/50
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6815 - accuracy: 0.8333
# Epoch 13/50
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6800 - accuracy: 0.8333
# Epoch 14/50
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6784 - accuracy: 0.8333
# Epoch 15/50
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6768 - accuracy: 0.8333
# Epoch 16/50
# 1/1 [==============================] - 0s 26ms/step - loss: 0.6752 - accuracy: 1.0000
# Epoch 17/50
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6735 - accuracy: 1.0000
# Epoch 18/50
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6718 - accuracy: 1.0000
# Epoch 19/50
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6701 - accuracy: 1.0000
# Epoch 20/50
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6683 - accuracy: 1.0000
# Epoch 21/50
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6665 - accuracy: 1.0000
# Epoch 22/50
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6646 - accuracy: 1.0000
# Epoch 23/50
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6627 - accuracy: 1.0000
# Epoch 24/50
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6607 - accuracy: 1.0000
# Epoch 25/50
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6587 - accuracy: 1.0000
# Epoch 26/50
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6566 - accuracy: 1.0000
# Epoch 27/50
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6544 - accuracy: 1.0000
# Epoch 28/50
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6522 - accuracy: 1.0000
# Epoch 29/50
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6499 - accuracy: 1.0000
# Epoch 30/50
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6475 - accuracy: 1.0000
# Epoch 31/50
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6451 - accuracy: 1.0000
# Epoch 32/50
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6425 - accuracy: 1.0000
# Epoch 33/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6399 - accuracy: 1.0000
# Epoch 34/50
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6371 - accuracy: 1.0000
# Epoch 35/50
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6343 - accuracy: 1.0000
# Epoch 36/50
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6313 - accuracy: 1.0000
# Epoch 37/50
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6283 - accuracy: 1.0000
# Epoch 38/50
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6251 - accuracy: 1.0000
# Epoch 39/50
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6218 - accuracy: 1.0000
# Epoch 40/50
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6184 - accuracy: 1.0000
# Epoch 41/50
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6148 - accuracy: 1.0000
# Epoch 42/50
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6111 - accuracy: 1.0000
# Epoch 43/50
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6072 - accuracy: 1.0000
# Epoch 44/50
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6032 - accuracy: 1.0000
# Epoch 45/50
# 1/1 [==============================] - 0s 21ms/step - loss: 0.5990 - accuracy: 1.0000
# Epoch 46/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.5946 - accuracy: 1.0000
# Epoch 47/50
# 1/1 [==============================] - 0s 26ms/step - loss: 0.5901 - accuracy: 1.0000
# Epoch 48/50
# 1/1 [==============================] - 0s 23ms/step - loss: 0.5854 - accuracy: 1.0000
# Epoch 49/50
# 1/1 [==============================] - 0s 21ms/step - loss: 0.5805 - accuracy: 1.0000
# Epoch 50/50
# 1/1 [==============================] - 0s 22ms/step - loss: 0.5754 - accuracy: 1.0000
